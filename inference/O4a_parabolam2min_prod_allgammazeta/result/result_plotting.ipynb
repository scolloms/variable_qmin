bf_76', 'ln_bf_77', 'ln_bf_78', 'ln_bf_79', 'ln_bf_8', 'ln_bf_80', 'ln_bf_81', 'ln_bf_82', 'ln_bf_83', 'ln_bf_84', 'ln_bf_85', 'ln_bf_86', 'ln_bf_87', 'ln_bf_88', 'ln_bf_89', 'ln_bf_9', 'ln_bf_90', 'ln_bf_91', 'ln_bf_92', 'ln_bf_93', 'ln_bf_94', 'ln_bf_95', 'ln_bf_96', 'ln_bf_97', 'ln_bf_98', 'ln_bf_99', 'log_10_rate', 'log_likelihood', 'log_prior', 'mmax', 'mmin', 'mpp', 'pdet_n_effective', 'rate', 'selection', 'selection_variance', 'sigpp', 'surveyed_hypervolume', 'var_0', 'var_1', 'var_10', 'var_100', 'var_101', 'var_102', 'var_103', 'var_104', 'var_105', 'var_106', 'var_107', 'var_108', 'var_109', 'var_11', 'var_110', 'var_111', 'var_112', 'var_113', 'var_114', 'var_115', 'var_116', 'var_117', 'var_118', 'var_119', 'var_12', 'var_120', 'var_121', 'var_122', 'var_123', 'var_124', 'var_125', 'var_126', 'var_127', 'var_128', 'var_129', 'var_13', 'var_130', 'var_131', 'var_132', 'var_133', 'var_134', 'var_135', 'var_136', 'var_137', 'var_138', 'var_139', 'var_14', 'var_140', 'var_141', 'var_142', 'var_143', 'var_144', 'var_145', 'var_146', 'var_147', 'var_148', 'var_149', 'var_15', 'var_150', 'var_151', 'var_152', 'var_153', 'var_154', 'var_155', 'var_156', 'var_157', 'var_16', 'var_17', 'var_18', 'var_19', 'var_2', 'var_20', 'var_21', 'var_22', 'var_23', 'var_24', 'var_25', 'var_26', 'var_27', 'var_28', 'var_29', 'var_3', 'var_30', 'var_31', 'var_32', 'var_33', 'var_34', 'var_35', 'var_36', 'var_37', 'var_38', 'var_39', 'var_4', 'var_40', 'var_41', 'var_42', 'var_43', 'var_44', 'var_45', 'var_46', 'var_47', 'var_48', 'var_49', 'var_5', 'var_50', 'var_51', 'var_52', 'var_53', 'var_54', 'var_55', 'var_56', 'var_57', 'var_58', 'var_59', 'var_6', 'var_60', 'var_61', 'var_62', 'var_63', 'var_64', 'var_65', 'var_66', 'var_67', 'var_68', 'var_69', 'var_7', 'var_70', 'var_71', 'var_72', 'var_73', 'var_74', 'var_75', 'var_76', 'var_77', 'var_78', 'var_79', 'var_8', 'var_80', 'var_81', 'var_82', 'var_83', 'var_84', 'var_85', 'var_86', 'var_87', 'var_88', 'var_89', 'var_9', 'var_90', 'var_91', 'var_92', 'var_93', 'var_94', 'var_95', 'var_96', 'var_97', 'var_98', 'var_99', 'variance', 'zeta']>

# %%
important_result = [result['posterior']['alpha'], result['posterior']['beta'], result['posterior']['gamma'],\
                    result['posterior']['mmin'], result['posterior']['mmax'], result['posterior']['zeta']]

# %%
prior = ConditionalPriorDict(filename='../../O4a-variablem2min-cond.prior')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File /cvmfs/software.igwn.org/conda/envs/igwn/lib/python3.10/site-packages/bilby/core/prior/base.py:448, in Prior._parse_argument_string(cls, val)
#     447 try:
# --> 448     val = eval(val, dict(), dict(np=np, inf=np.inf, pi=np.pi))
#     449 except NameError:
#
# File <string>:1
#
# NameError: name 'variable_qmin' is not defined
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 prior = ConditionalPriorDict(filename='../../O4a-variablem2min-cond.prior')
#
# File /cvmfs/software.igwn.org/conda/envs/igwn/lib/python3.10/site-packages/bilby/core/prior/dict.py:667, in ConditionalPriorDict.__init__(self, dictionary, filename, conversion_function)
#     665 self._rescale_indexes = []
#     666 self._least_recently_rescaled_keys = []
# --> 667 super(ConditionalPriorDict, self).__init__(
#     668     dictionary=dictionary,
#     669     filename=filename,
#     670     conversion_function=conversion_function,
#     671 )
#     672 self._resolved = False
#     673 self._resolve_conditions()
#
# File /cvmfs/software.igwn.org/conda/envs/igwn/lib/python3.10/site-packages/bilby/core/prior/dict.py:44, in PriorDict.__init__(self, dictionary, filename, conversion_function)
#      42     self.from_file(dictionary)
#      43 elif type(filename) is str:
# ---> 44     self.from_file(filename)
#      45 elif dictionary is not None:
#      46     raise ValueError("PriorDict input dictionary not understood")
#
# File /cvmfs/software.igwn.org/conda/envs/igwn/lib/python3.10/site-packages/bilby/core/prior/dict.py:158, in PriorDict.from_file(self, filename)
#     156         val = "=".join(elements[1:]).strip()
#     157         prior[key] = val
# --> 158 self.from_dictionary(prior)
#
# File /cvmfs/software.igwn.org/conda/envs/igwn/lib/python3.10/site-packages/bilby/core/prior/dict.py:279, in PriorDict.from_dictionary(self, dictionary)
#     277 else:
#     278     try:
# --> 279         dictionary[key] = cls.from_repr(args)
#     280     except TypeError as e:
#     281         raise TypeError(
#     282             "Unable to parse prior, bad entry: {} "
#     283             "= {}. Error message {}".format(key, val, e)
#     284         )
#
# File /cvmfs/software.igwn.org/conda/envs/igwn/lib/python3.10/site-packages/bilby/core/prior/base.py:335, in Prior.from_repr(cls, string)
#     332 @classmethod
#     333 def from_repr(cls, string):
#     334     """Generate the prior from its __repr__"""
# --> 335     return cls._from_repr(string)
#
# File /cvmfs/software.igwn.org/conda/envs/igwn/lib/python3.10/site-packages/bilby/core/prior/base.py:349, in Prior._from_repr(cls, string)
#     346     raise AttributeError('Unknown argument {} for class {}'.format(
#     347         key, cls.__name__))
#     348 else:
# --> 349     kwargs[key] = cls._parse_argument_string(val)
#     350 if key in ["condition_func", "conversion_function"] and isinstance(kwargs[key], str):
#     351     if "." in kwargs[key]:
#
# File /cvmfs/software.igwn.org/conda/envs/igwn/lib/python3.10/site-packages/bilby/core/prior/base.py:453, in Prior._parse_argument_string(cls, val)
#     451 module = '.'.join(val.split('.')[:-1])
#     452 func = val.split('.')[-1]
# --> 453 new_val = getattr(import_module(module), func, val)
#     454 if val == new_val:
#     455     raise TypeError(
#     456         "Cannot evaluate prior, "
#     457         f"failed to parse argument {val}"
#     458     )
#
# File /cvmfs/software.igwn.org/conda/envs/igwn/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1004, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'variable_qmin'

# %%
corner_kwargs = dict(
    bins=32,
    smooth=0.9,
    color="teal",
    #quantiles=[0.16, 0.84],
    levels=(1 - np.exp(-0.5), 1 - np.exp(-2), 1 - np.exp(-9 / 2.0)),
    plot_density=True,
    plot_datapoints=True,
    fill_contours=True,
    show_titles=True,
    hist_kwargs=dict(density=True),
    labels=['alpha','beta','gamma', 'mmin', 'mmax', 'zeta'],
)

# %%
corner.corner(np.swapaxes(important_result, 0,1), **corner_kwargs)

# %%
plt.hist(result['posterior']['gamma'])
# Out:
# (array([ 71., 159., 281., 385., 394., 397., 344., 244.,  88.,   8.]),
#  array([-0.47498814, -0.42990018, -0.38481222, -0.33972425, -0.29463629,
#         -0.24954833, -0.20446037, -0.15937241, -0.11428445, -0.06919649,
#         -0.02410853]),
#  <BarContainer object of 10 artists>)
